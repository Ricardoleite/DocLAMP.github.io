# %% [markdown]
# # Natural Convection

# %%
# %pylab inline
raw = open('/home/ricardo/Documents/Mag-NatConv/Figs-VT-B1-M120/Nu-B1-M120.txt').readlines()[:]
r1 = [ i.strip() for i in raw ]
r2 = ' '.join(r1)
uv = [ float(i) for i in re.split(' * ', r2) ]
Nu=np.array(uv[:]).reshape(len(Ra),len(Pr),len(Ha))
raw = open('/home/ricardo/Documents/Mag-NatConv/Figs-VT-B1-M120/Psi-B1-M120.txt').readlines()[:]
r1 = [ i.strip() for i in raw ]
r2 = ' '.join(r1)
uv = [ float(i) for i in re.split(' * ', r2) ]
Psi=np.array(uv[:]).reshape(len(Ra),len(Pr),len(Ha))

# %%
NuPr0H0= np.arange(len(Ra))*0.0; NuRa0H0= np.arange(len(Pr))*0.0
NuPr1H0= np.arange(len(Ra))*0.0; NuRa1H0= np.arange(len(Pr))*0.0
NuPr2H0= np.arange(len(Ra))*0.0; NuRa2H0= np.arange(len(Pr))*0.0
NuPr3H0= np.arange(len(Ra))*0.0; NuRa3H0= np.arange(len(Pr))*0.0
NuPr0H1= np.arange(len(Ra))*0.0; NuRa0H1= np.arange(len(Pr))*0.0
NuPr1H1= np.arange(len(Ra))*0.0; NuRa1H1= np.arange(len(Pr))*0.0
NuPr2H1= np.arange(len(Ra))*0.0; NuRa2H1= np.arange(len(Pr))*0.0
NuPr3H1= np.arange(len(Ra))*0.0; NuRa3H1= np.arange(len(Pr))*0.0
NuPr0H2= np.arange(len(Ra))*0.0; NuRa0H2= np.arange(len(Pr))*0.0
NuPr1H2= np.arange(len(Ra))*0.0; NuRa1H2= np.arange(len(Pr))*0.0
NuPr2H2= np.arange(len(Ra))*0.0; NuRa2H2= np.arange(len(Pr))*0.0
NuPr3H2= np.arange(len(Ra))*0.0; NuRa3H2= np.arange(len(Pr))*0.0

PsiPr0H0= np.arange(len(Ra))*0.0; PsiRa0H0= np.arange(len(Pr))*0.0
PsiPr1H0= np.arange(len(Ra))*0.0; PsiRa1H0= np.arange(len(Pr))*0.0
PsiPr2H0= np.arange(len(Ra))*0.0; PsiRa2H0= np.arange(len(Pr))*0.0
PsiPr3H0= np.arange(len(Ra))*0.0; PsiRa3H0= np.arange(len(Pr))*0.0
PsiPr0H1= np.arange(len(Ra))*0.0; PsiRa0H1= np.arange(len(Pr))*0.0
PsiPr1H1= np.arange(len(Ra))*0.0; PsiRa1H1= np.arange(len(Pr))*0.0
PsiPr2H1= np.arange(len(Ra))*0.0; PsiRa2H1= np.arange(len(Pr))*0.0
PsiPr3H1= np.arange(len(Ra))*0.0; PsiRa3H1= np.arange(len(Pr))*0.0
PsiPr0H2= np.arange(len(Ra))*0.0; PsiRa0H2= np.arange(len(Pr))*0.0
PsiPr1H2= np.arange(len(Ra))*0.0; PsiRa1H2= np.arange(len(Pr))*0.0
PsiPr2H2= np.arange(len(Ra))*0.0; PsiRa2H2= np.arange(len(Pr))*0.0
PsiPr3H2= np.arange(len(Ra))*0.0; PsiRa3H2= np.arange(len(Pr))*0.0
for i in range (len(Ra)):
    NuPr0H0[i]="{:.2f}".format(Nu[i][0][0])
    NuPr1H0[i]="{:.2f}".format(Nu[i][1][0])
    NuPr2H0[i]="{:.2f}".format(Nu[i][2][0])
    NuPr3H0[i]="{:.2f}".format(Nu[i][3][0])
    NuPr0H1[i]="{:.2f}".format(Nu[i][0][1])
    NuPr1H1[i]="{:.2f}".format(Nu[i][1][1])
    NuPr2H1[i]="{:.2f}".format(Nu[i][2][1])
    NuPr3H1[i]="{:.2f}".format(Nu[i][3][1])
    NuPr0H2[i]="{:.2f}".format(Nu[i][0][2])
    NuPr1H2[i]="{:.2f}".format(Nu[i][1][2])
    NuPr2H2[i]="{:.2f}".format(Nu[i][2][2])
    NuPr3H2[i]="{:.2f}".format(Nu[i][3][2])
for i in range (len(Pr)):
    NuRa0H0[i]="{:.2f}".format(Nu[0][i][0])
    NuRa1H0[i]="{:.2f}".format(Nu[1][i][0])
    NuRa2H0[i]="{:.2f}".format(Nu[2][i][0])
    NuRa3H0[i]="{:.2f}".format(Nu[3][i][0])
    NuRa0H1[i]="{:.2f}".format(Nu[0][i][1])
    NuRa1H1[i]="{:.2f}".format(Nu[1][i][1])
    NuRa2H1[i]="{:.2f}".format(Nu[2][i][1])
    NuRa3H1[i]="{:.2f}".format(Nu[3][i][1])
    NuRa0H2[i]="{:.2f}".format(Nu[0][i][2])
    NuRa1H2[i]="{:.2f}".format(Nu[1][i][2])
    NuRa2H2[i]="{:.2f}".format(Nu[2][i][2])
    NuRa3H2[i]="{:.2f}".format(Nu[3][i][2])
for i in range (len(Ra)):
    PsiPr0H0[i]="{:.2f}".format(Psi[i][0][0])
    PsiPr1H0[i]="{:.2f}".format(Psi[i][1][0])
    PsiPr2H0[i]="{:.2f}".format(Psi[i][2][0])
    PsiPr3H0[i]="{:.2f}".format(Psi[i][3][0])
    PsiPr0H1[i]="{:.2f}".format(Psi[i][0][1])
    PsiPr1H1[i]="{:.2f}".format(Psi[i][1][1])
    PsiPr2H1[i]="{:.2f}".format(Psi[i][2][1])
    PsiPr3H1[i]="{:.2f}".format(Psi[i][3][1])
    PsiPr0H2[i]="{:.2f}".format(Psi[i][0][2])
    PsiPr1H2[i]="{:.2f}".format(Psi[i][1][2])
    PsiPr2H2[i]="{:.2f}".format(Psi[i][2][2])
    PsiPr3H2[i]="{:.2f}".format(Psi[i][3][2])
for i in range (len(Pr)):
    PsiRa0H0[i]="{:.2f}".format(Psi[0][i][0])
    PsiRa1H0[i]="{:.2f}".format(Psi[1][i][0])
    PsiRa2H0[i]="{:.2f}".format(Psi[2][i][0])
    PsiRa0H1[i]="{:.2f}".format(Psi[0][i][1])
    PsiRa1H1[i]="{:.2f}".format(Psi[1][i][1])
    PsiRa2H1[i]="{:.2f}".format(Psi[2][i][1])
    PsiRa0H2[i]="{:.2f}".format(Psi[0][i][2])
    PsiRa1H2[i]="{:.2f}".format(Psi[1][i][2])
    PsiRa2H2[i]="{:.2f}".format(Psi[2][i][2])

# %%
print(NuRa0H0)
print(NuRa0H1)
print(NuRa0H2)
# Out:
# [1.01 1.01 1.01 1.01]
# [1.01 1.01 1.01 1.01]
# [1.01 1.01 1.01 1.01]

# %% [markdown]
# ## Square Enclosure
#
# Consider a two-dimensional enclosure of height $H$ and horizontal length $L$. The enclosure is filled with a Newtonian fluid such as air or water.

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg  "width:100%"
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-baqh"></th>
#     <th class="tg-baqh" colspan="8">$Ra=10^{3}$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh" colspan="4">Campo de Streamlines</td>
#     <td class="tg-baqh" colspan="4">Linhas Isotermas</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=0$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=50$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax" rowspan="2">$Ha=100$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-baqh"></th>
#     <th class="tg-baqh" colspan="8">$Ra=10^{4}$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh" colspan="4">Campo de Streamlines</td>
#     <td class="tg-baqh" colspan="4">Linhas Isotermas</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=0$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=50$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax" rowspan="2">$Ha=100$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=10000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=10000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-baqh"></th>
#     <th class="tg-baqh" colspan="8">$Ra=10^{4}$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh" colspan="4">Campo de Streamlines</td>
#     <td class="tg-baqh" colspan="4">Linhas Isotermas</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=0$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=50$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax" rowspan="2">$Ha=100$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=100000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=100000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-baqh"></th>
#     <th class="tg-baqh" colspan="8">$Ra=10^{4}$</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh" colspan="4">Campo de Streamlines</td>
#     <td class="tg-baqh" colspan="4">Linhas Isotermas</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#     <td class="tg-baqh">$Pr=0.05$</td>
#     <td class="tg-baqh">$Pr=0.10$</td>
#     <td class="tg-baqh">$Pr=0.50$</td>
#     <td class="tg-baqh">$Pr=1.00$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=0$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.050-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.100-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.500-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=1.000-Ha=0-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="2">$Ha=50$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.050-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.100-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.500-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=1.000-Ha=50-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax" rowspan="2">$Ha=100$</td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/StF-Ra=1000000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.050-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.100-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=0.500-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#     <td class="tg-baqh"><img src="Figs-VT-B1-M120/IsoT-Ra=1000000-Pr=1.000-Ha=100-B=1-P=1-N=120.png" style="width:100px;height:100px"/></td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$\Psi_{max}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#     <td class="tg-baqh">$Nu_{av}=XX$</td>
#   </tr>
# </tbody>
# </table>

# %%
matplotlib.rcParams['mathtext.fontset'] = 'cm'
plt.semilogx(Ra,NuPr0H0,'ko:',fillstyle='none')
plt.semilogx(Ra,NuPr1H0,'ks:',fillstyle='none')
plt.semilogx(Ra,NuPr2H0,'k>:',fillstyle='none')
plt.semilogx(Ra,NuPr3H0,'kd:',fillstyle='none')
plt.semilogx(Ra,NuPr0H1,'ro:',fillstyle='none')
plt.semilogx(Ra,NuPr1H1,'rs:',fillstyle='none')
plt.semilogx(Ra,NuPr2H1,'r>:',fillstyle='none')
plt.semilogx(Ra,NuPr3H1,'rd:',fillstyle='none')
plt.semilogx(Ra,NuPr0H2,'bo:',fillstyle='none')
plt.semilogx(Ra,NuPr1H2,'bs:',fillstyle='none')
plt.semilogx(Ra,NuPr2H2,'b>:',fillstyle='none')
plt.semilogx(Ra,NuPr3H2,'bd:',fillstyle='none')
plt.ylabel('$Nu_{av}$', color='k', horizontalalignment='right',rotation=0, fontsize=20)
plt.xlabel('$Ra$', fontsize=20)
plt.legend(['$Pr=0.05-Ha=0$','$Pr=0.1-Ha=0$','$Pr=0.5-Ha=0$','$Pr=1.0-Ha=0$',
           '$Pr=0.05-Ha=50$','$Pr=0.1-Ha=50$','$Pr=0.5-Ha=50$','$Pr=1.0-Ha=50$',
           '$Pr=0.05-Ha=100$','$Pr=0.1-Ha=100$','$Pr=0.5-Ha=100$','$Pr=1.0-Ha=100$'],fontsize=11.,bbox_to_anchor=(1.0, 1.02))
plt.show()

# %%
matplotlib.rcParams['mathtext.fontset'] = 'cm'
plt.semilogx(Ra,NuRa0H0,'ko:',fillstyle='none')
plt.semilogx(Ra,NuRa1H0,'ko:',fillstyle='none')
plt.semilogx(Ra,NuRa2H0,'ko:',fillstyle='none')
plt.semilogx(Ra,NuRa3H0,'ko:',fillstyle='none')
plt.show()

# %%
print(NuRa0H0)
print(NuRa1H0)
print(NuRa2H0)
print(NuRa3H0)
# Out:
# [1.01 1.01 1.01 1.01]
# [1.34 1.37 1.4  1.4 ]
# [3.59 3.88 4.21 4.27]
# [6.95 7.44 8.5  8.74]

# %%
matplotlib.rcParams['mathtext.fontset'] = 'cm'
plt.semilogx(Ra,PsiPr0H0,'ko:',fillstyle='none')
plt.semilogx(Ra,PsiPr1H0,'ks:',fillstyle='none')
plt.semilogx(Ra,PsiPr2H0,'k>:',fillstyle='none')
plt.semilogx(Ra,PsiPr3H0,'kd:',fillstyle='none')
plt.semilogx(Ra,PsiPr0H1,'ro:',fillstyle='none')
plt.semilogx(Ra,PsiPr1H1,'rs:',fillstyle='none')
plt.semilogx(Ra,PsiPr2H1,'r>:',fillstyle='none')
plt.semilogx(Ra,PsiPr3H1,'rd:',fillstyle='none')
plt.semilogx(Ra,PsiPr0H2,'bo:',fillstyle='none')
plt.semilogx(Ra,PsiPr1H2,'bs:',fillstyle='none')
plt.semilogx(Ra,PsiPr2H2,'b>:',fillstyle='none')
plt.semilogx(Ra,PsiPr3H2,'bd:',fillstyle='none')
plt.ylabel('$\\Psi_{max}$', color='k', horizontalalignment='right',rotation=0, fontsize=20)
plt.xlabel('$Ra$', fontsize=20)
plt.legend(['$Pr=0.05-Ha=0$','$Pr=0.1-Ha=0$','$Pr=0.5-Ha=0$','$Pr=1.0-Ha=0$',
           '$Pr=0.05-Ha=50$','$Pr=0.1-Ha=50$','$Pr=0.5-Ha=50$','$Pr=1.0-Ha=50$',
           '$Pr=0.05-Ha=100$','$Pr=0.1-Ha=100$','$Pr=0.5-Ha=100$','$Pr=1.0-Ha=100$'],fontsize=11.,bbox_to_anchor=(1.0, 1.02))
plt.show()
